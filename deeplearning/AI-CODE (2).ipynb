# %% [markdown]
# # AI 정리 코드

# %%
# 기본 import

from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns
import pandas as pd
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## < Pre-trained model >

# %%
# model save

base_loss,base_accuracy=model.evaluate(test_X, test_y)

model_file='C:/ai/dataset/Pretrained_Model.h5'
  
tf.keras.models.save_model(model, model_file, include_optimizer=False)
print('model saved at ', model_file)
score=base_accuracy*100
print('Accuracy >{:f}'.format(score))
print('Base Loss >{:.2f}'.format(base_loss))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0033 - mse: 0.0031
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# model saved at  C:/ai/dataset/Pretrained_Model.h5
# Accuracy >0.319253
# Base Loss >0.00

# %%
# model load

from tensorflow.keras.models import load_model

base_model = load_model(model_file)
base_model.compile(optimizer = 'rmsprop', loss = 'mse', metrics = ['mse'])

base_model.evaluate(test_X, test_y)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0033 - mse: 0.0031
# [0.0035583418793976307, 0.003192533040419221]

# %%
# 기존 모델의 층을 동결 (학습되지 않도록 설정)

base_model.trainable = False

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, models

def remove_last_layers(model, num_layers_to_remove):
    # 모델의 레이어를 하나씩 슬라이스해서 앞의 레이어만 가져옴
    model_layers = model.layers[:-num_layers_to_remove]  # 마지막 레이어부터 지정된 갯수만큼 제외
    new_model = models.Sequential(model_layers)  # 새로운 모델에 해당 레이어들만 추가
    return new_model

# %%
# 출력층부터 1개의 레이어를 삭제
new_model = remove_last_layers(base_model, 1)

# 새로운 출력층 추가
new_model.add(layers.Dense(256, activation='relu'))
new_model.add(layers.Dense(1))  # 예: 10개의 클래스
new_model.compile(optimizer = 'rmsprop', loss = 'mse', metrics = ['mse'])

# 모델 요약 출력
new_model.summary()
# Out:
# Model: "sequential_36"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_16 (LSTM)                  │ (None, 10, 20)         │         2,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 10, 20)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_17 (LSTM)                  │ (None, 20)             │         3,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_170 (Dense)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_171 (Dense)               │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,280 (20.62 KB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 5,280 (20.62 KB)

# %%
history2=new_model.fit(train_X, train_y, epochs=70, batch_size=30, validation_split = 0.1, shuffle = True)
# Out:
# Epoch 1/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0934 - mse: 0.0940 - val_loss: 0.0138 - val_mse: 0.0134
# Epoch 2/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073 - mse: 0.0074 - val_loss: 0.0147 - val_mse: 0.0111
# Epoch 3/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0141 - val_mse: 0.0108
# Epoch 4/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0138 - val_mse: 0.0106
# Epoch 5/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0056 - mse: 0.0057 - val_loss: 0.0184 - val_mse: 0.0111
# Epoch 6/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - mse: 0.0051 - val_loss: 0.0151 - val_mse: 0.0102
# Epoch 7/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0116 - val_mse: 0.0136
# Epoch 8/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0297 - val_mse: 0.0184
# Epoch 9/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0114 - val_mse: 0.0147
# Epoch 10/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0054 - mse: 0.0053 - val_loss: 0.0132 - val_mse: 0.0203
# Epoch 11/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0124 - val_mse: 0.0106
# Epoch 12/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0135 - val_mse: 0.0101
# Epoch 13/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - mse: 0.0053 - val_loss: 0.0139 - val_mse: 0.0101
# Epoch 14/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - mse: 0.0058 - val_loss: 0.0222 - val_mse: 0.0136
# Epoch 15/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - mse: 0.0046 - val_loss: 0.0113 - val_mse: 0.0148
# Epoch 16/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0129 - val_mse: 0.0102
# Epoch 17/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0111 - val_mse: 0.0126
# Epoch 18/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0116 - val_mse: 0.0118
# Epoch 19/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0110 - val_mse: 0.0130
# Epoch 20/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0127 - val_mse: 0.0194
# Epoch 21/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0161 - val_mse: 0.0107
# Epoch 22/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mse: 0.0045 - val_loss: 0.0127 - val_mse: 0.0102
# Epoch 23/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044 - mse: 0.0045 - val_loss: 0.0118 - val_mse: 0.0108
# Epoch 24/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0122 - val_mse: 0.0104
# Epoch 25/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0133 - val_mse: 0.0102
# Epoch 26/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0165 - val_mse: 0.0107
# Epoch 27/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0131 - val_mse: 0.0201
# Epoch 28/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0051 - mse: 0.0052 - val_loss: 0.0144 - val_mse: 0.0101
# Epoch 29/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0110 - val_mse: 0.0120
# Epoch 30/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0151 - val_mse: 0.0104
# Epoch 31/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0119 - val_mse: 0.0109
# Epoch 32/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0116 - val_mse: 0.0106
# Epoch 33/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0147 - val_mse: 0.0103
# Epoch 34/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0118 - val_mse: 0.0165
# Epoch 35/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0123 - val_mse: 0.0106
# Epoch 36/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0132 - val_mse: 0.0102
# Epoch 37/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0180 - val_mse: 0.0112
# Epoch 38/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mse: 0.0048 - val_loss: 0.0225 - val_mse: 0.0136
# Epoch 39/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0148 - val_mse: 0.0102
# Epoch 40/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0116 - val_mse: 0.0125
# Epoch 41/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0162 - val_mse: 0.0105
# Epoch 42/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0119 - val_mse: 0.0152
# Epoch 43/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0189 - val_mse: 0.0118
# Epoch 44/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mse: 0.0049 - val_loss: 0.0114 - val_mse: 0.0117
# Epoch 45/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mse: 0.0039 - val_loss: 0.0147 - val_mse: 0.0237
# Epoch 46/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - mse: 0.0058 - val_loss: 0.0112 - val_mse: 0.0120
# Epoch 47/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0114 - val_mse: 0.0125
# Epoch 48/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - mse: 0.0039 - val_loss: 0.0159 - val_mse: 0.0103
# Epoch 49/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0053 - mse: 0.0054 - val_loss: 0.0119 - val_mse: 0.0154
# Epoch 50/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mse: 0.0045 - val_loss: 0.0150 - val_mse: 0.0103
# Epoch 51/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0184 - val_mse: 0.0114
# Epoch 52/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0114 - val_mse: 0.0124
# Epoch 53/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0265 - val_mse: 0.0167
# Epoch 54/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0160 - val_mse: 0.0104
# Epoch 55/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - mse: 0.0039 - val_loss: 0.0125 - val_mse: 0.0098
# Epoch 56/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0157 - val_mse: 0.0104
# Epoch 57/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0164 - val_mse: 0.0106
# Epoch 58/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0111 - val_mse: 0.0134
# Epoch 59/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0185 - val_mse: 0.0116
# Epoch 60/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0119 - val_mse: 0.0162
# Epoch 61/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0119 - val_mse: 0.0160
# Epoch 62/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0055 - mse: 0.0054 - val_loss: 0.0143 - val_mse: 0.0225
# Epoch 63/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0144 - val_mse: 0.0100
# Epoch 64/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mse: 0.0040 - val_loss: 0.0113 - val_mse: 0.0122
# Epoch 65/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0144 - val_mse: 0.0100
# Epoch 66/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0126 - val_mse: 0.0102
# Epoch 67/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0124 - val_mse: 0.0105
# Epoch 68/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0118 - val_mse: 0.0104
# Epoch 69/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0117 - val_mse: 0.0115
# Epoch 70/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0197 - val_mse: 0.0119

# %%
plt.plot(history2.history["loss"], label = "train")
plt.plot(history2.history["val_loss"], label = "test")
plt.legend()

test_loss, test_acc = new_model.evaluate(test_X, test_y)
print("test accuracy: ", test_acc)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0061 - mse: 0.0057
# test accuracy:  0.008366592228412628

# %%
stock_AJ = stock[stock['Code']=='A095570']
stock_AJ = stock_AJ [['Date', 'Open', 'High', 'Low', 'Close', 'Volume']]
stock_AJ
# Out:
#             Date  Open  High   Low  Close  Volume
# 1       20210601  5860  5940  5750   5780   63836
# 2001    20210602  5840  5840  5750   5800   39320
# 4001    20210603  5800  5800  5650   5720   78440
# 6001    20210604  5720  5720  5420   5570  198246
# 8001    20210607  5650  5660  5370   5420  167712
# ...          ...   ...   ...   ...    ...     ...
# 978001  20230523  4430  4445  4405   4430   83616
# 980001  20230524  4430  4515  4380   4450  251478
# 982001  20230525  4450  4490  4400   4415   83314
# 984001  20230526  4445  4445  4320   4325  206735
# 986001  20230530  4345  4395  4300   4330  126253
#
# [494 rows x 6 columns]

# %%
# 두 데이터를 리스트 형태로 저장
dfx = stock_AJ[['Open','High','Low','Volume', 'Close']]
dfx = MinMaxScaler(dfx)
dfy = dfx[['Close']]
dfx = dfx[['Open','High','Low','Volume']]

X = dfx.values.tolist()
y = dfy.values.tolist()
window_size = 10

data_X = []
data_y = []
for i in range(len(y) - window_size):
    _X = X[i : i + window_size] # 다음 날 종가(i+windows_size)는 포함되지 않음
    _y = y[i + window_size]     # 다음 날 종가
    data_X.append(_X)
    data_y.append(_y)

# %%
print('전체 데이터의 크기 :', len(data_X), len(data_y))

train_size = int(len(data_y) * 0.7)
train_X = np.array(data_X[0 : train_size])
train_y = np.array(data_y[0 : train_size])

test_size = len(data_y) - train_size
test_X = np.array(data_X[train_size : len(data_X)])
test_y = np.array(data_y[train_size : len(data_y)])

print('훈련 데이터의 크기 :', train_X.shape, train_y.shape)
print('테스트 데이터의 크기 :', test_X.shape, test_y.shape)
# Out:
# 전체 데이터의 크기 : 484 484
# 훈련 데이터의 크기 : (338, 10, 4) (338, 1)
# 테스트 데이터의 크기 : (146, 10, 4) (146, 1)

# %%
# 출력층부터 1개의 레이어를 삭제
new_model = remove_last_layers(base_model, 1)

# 새로운 출력층 추가
new_model.add(layers.Dense(256, activation='relu'))
new_model.add(layers.Dense(1))  # 예: 10개의 클래스
new_model.compile(optimizer = 'rmsprop', loss = 'mse', metrics = ['mse'])

# 모델 요약 출력
new_model.summary()
# Out:
# Model: "sequential_37"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_16 (LSTM)                  │ (None, 10, 20)         │         2,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 10, 20)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_17 (LSTM)                  │ (None, 20)             │         3,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_172 (Dense)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_173 (Dense)               │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,280 (20.62 KB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 5,280 (20.62 KB)

# %%
history3=new_model.fit(train_X, train_y, epochs=70, batch_size=30, validation_split = 0.1, shuffle = True)
# Out:
# Epoch 1/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1330 - mse: 0.1336 - val_loss: 0.0147 - val_mse: 0.0166
# Epoch 2/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102 - mse: 0.0103 - val_loss: 0.0144 - val_mse: 0.0132
# Epoch 3/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0134 - val_mse: 0.0136
# Epoch 4/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0080 - mse: 0.0078 - val_loss: 0.0260 - val_mse: 0.0147
# Epoch 5/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0122 - val_mse: 0.0141
# Epoch 6/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0144 - val_mse: 0.0103
# Epoch 7/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mse: 0.0047 - val_loss: 0.0118 - val_mse: 0.0128
# Epoch 8/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0053 - mse: 0.0052 - val_loss: 0.0146 - val_mse: 0.0102
# Epoch 9/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0144 - val_mse: 0.0102
# Epoch 10/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0161 - val_mse: 0.0105
# Epoch 11/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0056 - mse: 0.0055 - val_loss: 0.0154 - val_mse: 0.0103
# Epoch 12/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0058 - mse: 0.0056 - val_loss: 0.0288 - val_mse: 0.0182
# Epoch 13/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mse: 0.0050 - val_loss: 0.0122 - val_mse: 0.0103
# Epoch 14/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0053 - mse: 0.0054 - val_loss: 0.0120 - val_mse: 0.0106
# Epoch 15/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - mse: 0.0048 - val_loss: 0.0217 - val_mse: 0.0134
# Epoch 16/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048 - mse: 0.0049 - val_loss: 0.0177 - val_mse: 0.0113
# Epoch 17/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0111 - val_mse: 0.0134
# Epoch 18/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0176 - val_mse: 0.0113
# Epoch 19/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mse: 0.0046 - val_loss: 0.0111 - val_mse: 0.0131
# Epoch 20/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0113 - val_mse: 0.0140
# Epoch 21/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0161 - val_mse: 0.0104
# Epoch 22/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0113 - val_mse: 0.0119
# Epoch 23/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0192 - val_mse: 0.0119
# Epoch 24/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0111 - val_mse: 0.0125
# Epoch 25/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mse: 0.0046 - val_loss: 0.0123 - val_mse: 0.0102
# Epoch 26/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0256 - val_mse: 0.0153
# Epoch 27/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0187 - val_mse: 0.0116
# Epoch 28/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0121 - val_mse: 0.0107
# Epoch 29/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0115 - val_mse: 0.0127
# Epoch 30/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mse: 0.0049 - val_loss: 0.0136 - val_mse: 0.0102
# Epoch 31/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0054 - mse: 0.0053 - val_loss: 0.0112 - val_mse: 0.0134
# Epoch 32/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mse: 0.0050 - val_loss: 0.0164 - val_mse: 0.0106
# Epoch 33/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0230 - val_mse: 0.0142
# Epoch 34/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0131 - val_mse: 0.0102
# Epoch 35/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0113 - val_mse: 0.0123
# Epoch 36/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0205 - val_mse: 0.0124
# Epoch 37/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - mse: 0.0053 - val_loss: 0.0124 - val_mse: 0.0104
# Epoch 38/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mse: 0.0047 - val_loss: 0.0186 - val_mse: 0.0117
# Epoch 39/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0116 - val_mse: 0.0109
# Epoch 40/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mse: 0.0045 - val_loss: 0.0227 - val_mse: 0.0142
# Epoch 41/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0126 - val_mse: 0.0101
# Epoch 42/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0113 - val_mse: 0.0147
# Epoch 43/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0119 - val_mse: 0.0107
# Epoch 44/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0111 - val_mse: 0.0117
# Epoch 45/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0176 - val_mse: 0.0112
# Epoch 46/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mse: 0.0044 - val_loss: 0.0239 - val_mse: 0.0150
# Epoch 47/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0115 - val_mse: 0.0107
# Epoch 48/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mse: 0.0042 - val_loss: 0.0116 - val_mse: 0.0108
# Epoch 49/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0191 - val_mse: 0.0119
# Epoch 50/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0199 - val_mse: 0.0122
# Epoch 51/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mse: 0.0042 - val_loss: 0.0120 - val_mse: 0.0170
# Epoch 52/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0126 - val_mse: 0.0103
# Epoch 53/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0116 - val_mse: 0.0150
# Epoch 54/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mse: 0.0043 - val_loss: 0.0194 - val_mse: 0.0121
# Epoch 55/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mse: 0.0046 - val_loss: 0.0123 - val_mse: 0.0106
# Epoch 56/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0114 - val_mse: 0.0140
# Epoch 57/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0130 - val_mse: 0.0102
# Epoch 58/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mse: 0.0047 - val_loss: 0.0262 - val_mse: 0.0160
# Epoch 59/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - mse: 0.0053 - val_loss: 0.0145 - val_mse: 0.0102
# Epoch 60/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0134 - val_mse: 0.0102
# Epoch 61/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0116 - val_mse: 0.0115
# Epoch 62/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0137 - val_mse: 0.0101
# Epoch 63/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0112 - val_mse: 0.0117
# Epoch 64/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0165 - val_mse: 0.0107
# Epoch 65/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0174 - val_mse: 0.0109
# Epoch 66/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0128 - val_mse: 0.0101
# Epoch 67/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0117 - val_mse: 0.0115
# Epoch 68/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0174 - val_mse: 0.0110
# Epoch 69/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0141 - val_mse: 0.0101
# Epoch 70/70
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mse: 0.0036 - val_loss: 0.0122 - val_mse: 0.0099

# %%
plt.plot(history3.history["loss"], label = "train")
plt.plot(history3.history["val_loss"], label = "test")
plt.legend()

test_loss, test_acc = new_model.evaluate(test_X, test_y)
print("test accuracy: ", test_acc)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0036 - mse: 0.0034
# test accuracy:  0.004882059991359711

# %% [markdown]
# ## < PCA >

# %%
# 데이터 불러오기 (csv, xlsx)

df = pd.read_csv("C:/ai/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error

# 데이터에서 독립 변수(Outcome 제외)를 추출
X = df.drop('Outcome', axis=1)

X_scaled = StandardScaler().fit_transform(X)
pca = PCA(n_components=5)
X_pca = pca.fit_transform(X_scaled)
for i in range(5):
    # LabelEncoder 객체 생성
    label_encoder = LabelEncoder()
    # 'label' 컬럼을 숫자로 변환
    X_pca[:,i] = LabelEncoder().fit_transform(X_pca[:,i])

# %%
# 축소된 데이터 복원 (원래 차원으로 복원)
X_reconstructed = pca.inverse_transform(X_pca)

# 원본 데이터와 복원된 데이터 비교 (MSE 계산)
mse = mean_squared_error(X_scaled, X_reconstructed)
print("mse: ",mse)
# Out:
# mse:  122344.42320683316

# %%
df_e=df.copy()
for i in df.columns:
    # LabelEncoder 객체 생성
    label_encoder = LabelEncoder()
    # 'label' 컬럼을 숫자로 변환
    df_e[i] = LabelEncoder().fit_transform(df[i])
df_e
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0              6       86             22             28        0  123
# 1              1       23             19             22        0   62
# 2              8      121             17              0        0   30
# 3              1       27             19             16       62   77
# 4              0       75              4             28      102  209
# ..           ...      ...            ...            ...      ...  ...
# 763           10       39             25             41      108  118
# 764            2       60             21             20        0  155
# 765            5       59             22             16       71   58
# 766            1       64             14              0        0   95
# 767            1       31             21             24        0   98
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                         350   29        1
# 1                         196   10        0
# 2                         368   11        1
# 3                          53    0        0
# 4                         514   12        1
# ..                        ...  ...      ...
# 763                        55   42        0
# 764                       187    6        0
# 765                       115    9        0
# 766                       195   26        1
# 767                       169    2        0
#
# [768 rows x 9 columns]

# %%
X=df_e.drop('Outcome',axis=1).values
y=pd.get_dummies(df_e['Outcome']).values
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=0)
X_train_p, X_test_p, y_train_p, y_test_p = train_test_split(X_pca, y,test_size=0.25,random_state=0)

# %%
# 딥러닝 모델

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam


model = Sequential()

model.add(Dense(15,input_shape=(X_train.shape[1],),activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(5,activation='sigmoid'))
model.add(Dense(y_train.shape[1],activation='softmax'))

#model.compile(Adam(learning_rate=0.02),'binary_crossentropy',metrics=['accuracy'])
model.compile(Adam(learning_rate=0.002),'categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# C:\Users\1563a\anaconda3\lib\site-packages\keras\src\layers\core\dense.py:85: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_42"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_190 (Dense)               │ (None, 15)             │           135 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_191 (Dense)               │ (None, 10)             │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_192 (Dense)               │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_193 (Dense)               │ (None, 2)              │            12 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 362 (1.41 KB)
#  Trainable params: 362 (1.41 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 딥러닝 훈련

model_history=model.fit(x=X_train, y=y_train, epochs=20, batch_size=4,validation_split=0.1)
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6426 - loss: 0.6576 - val_accuracy: 0.6724 - val_loss: 0.6305
# Epoch 2/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - accuracy: 0.6362 - loss: 0.6563 - val_accuracy: 0.6724 - val_loss: 0.6289
# Epoch 3/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - accuracy: 0.6224 - loss: 0.6588 - val_accuracy: 0.6724 - val_loss: 0.6230
# Epoch 4/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.6351 - loss: 0.6498 - val_accuracy: 0.6724 - val_loss: 0.6237
# Epoch 5/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - accuracy: 0.6473 - loss: 0.6360 - val_accuracy: 0.6724 - val_loss: 0.6217
# Epoch 6/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step - accuracy: 0.6404 - loss: 0.6338 - val_accuracy: 0.6724 - val_loss: 0.6131
# Epoch 7/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - accuracy: 0.6094 - loss: 0.6477 - val_accuracy: 0.6724 - val_loss: 0.6089
# Epoch 8/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - accuracy: 0.6092 - loss: 0.6412 - val_accuracy: 0.6724 - val_loss: 0.6048
# Epoch 9/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step - accuracy: 0.6717 - loss: 0.5941 - val_accuracy: 0.6724 - val_loss: 0.6166
# Epoch 10/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.6558 - loss: 0.5953 - val_accuracy: 0.6724 - val_loss: 0.6075
# Epoch 11/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - accuracy: 0.6608 - loss: 0.5807 - val_accuracy: 0.6207 - val_loss: 0.6149
# Epoch 12/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step - accuracy: 0.6781 - loss: 0.6134 - val_accuracy: 0.6724 - val_loss: 0.5993
# Epoch 13/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.6752 - loss: 0.5849 - val_accuracy: 0.6552 - val_loss: 0.6008
# Epoch 14/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - accuracy: 0.6717 - loss: 0.5853 - val_accuracy: 0.7241 - val_loss: 0.6021
# Epoch 15/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - accuracy: 0.7007 - loss: 0.5748 - val_accuracy: 0.6897 - val_loss: 0.5847
# Epoch 16/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - accuracy: 0.7076 - loss: 0.5763 - val_accuracy: 0.6724 - val_loss: 0.5925
# Epoch 17/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.6840 - loss: 0.5499 - val_accuracy: 0.6552 - val_loss: 0.6230
# Epoch 18/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.7226 - loss: 0.5627 - val_accuracy: 0.6724 - val_loss: 0.6106
# Epoch 19/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - accuracy: 0.7314 - loss: 0.5543 - val_accuracy: 0.6724 - val_loss: 0.6347
# Epoch 20/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - accuracy: 0.7009 - loss: 0.5578 - val_accuracy: 0.7414 - val_loss: 0.5807
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.76       130
#            1       0.50      0.48      0.49        62
#
#     accuracy                           0.68       192
#    macro avg       0.63      0.63      0.63       192
# weighted avg       0.67      0.68      0.68       192
#
# [[100  30]
#  [ 32  30]]

# %%
# 딥러닝 모델

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam


model = Sequential()

model.add(Dense(15,input_shape=(X_train_p.shape[1],),activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(5,activation='sigmoid'))
model.add(Dense(y_train_p.shape[1],activation='softmax'))

#model.compile(Adam(learning_rate=0.02),'binary_crossentropy',metrics=['accuracy'])
model.compile(Adam(learning_rate=0.002),'categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_44"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_198 (Dense)               │ (None, 15)             │            90 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_199 (Dense)               │ (None, 10)             │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_200 (Dense)               │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_201 (Dense)               │ (None, 2)              │            12 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 317 (1.24 KB)
#  Trainable params: 317 (1.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 딥러닝 훈련

model_history2=model.fit(x=X_train_p, y=y_train_p, epochs=20, batch_size=4,validation_split=0.1)
y_pred_p = model.predict(X_test_p)

y_test_class_p = np.argmax(y_test_p,axis=1)
y_pred_class_p = np.argmax(y_pred_p,axis=1)
# Out:
# Epoch 1/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4821 - loss: 0.7023 - val_accuracy: 0.6724 - val_loss: 0.6307
# Epoch 2/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - accuracy: 0.6385 - loss: 0.6523 - val_accuracy: 0.6724 - val_loss: 0.6262
# Epoch 3/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - accuracy: 0.6509 - loss: 0.6432 - val_accuracy: 0.6724 - val_loss: 0.6298
# Epoch 4/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - accuracy: 0.6301 - loss: 0.6538 - val_accuracy: 0.6724 - val_loss: 0.6232
# Epoch 5/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.6187 - loss: 0.6609 - val_accuracy: 0.6724 - val_loss: 0.6188
# Epoch 6/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.6600 - loss: 0.6330 - val_accuracy: 0.6724 - val_loss: 0.6148
# Epoch 7/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step - accuracy: 0.6112 - loss: 0.6505 - val_accuracy: 0.6724 - val_loss: 0.6072
# Epoch 8/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - accuracy: 0.6510 - loss: 0.6356 - val_accuracy: 0.6724 - val_loss: 0.6127
# Epoch 9/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step - accuracy: 0.6182 - loss: 0.6483 - val_accuracy: 0.6724 - val_loss: 0.6019
# Epoch 10/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - accuracy: 0.6372 - loss: 0.6221 - val_accuracy: 0.6724 - val_loss: 0.5829
# Epoch 11/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - accuracy: 0.6328 - loss: 0.6307 - val_accuracy: 0.7241 - val_loss: 0.5775
# Epoch 12/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - accuracy: 0.6429 - loss: 0.6321 - val_accuracy: 0.6724 - val_loss: 0.6038
# Epoch 13/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - accuracy: 0.6526 - loss: 0.6226 - val_accuracy: 0.6552 - val_loss: 0.6009
# Epoch 14/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - accuracy: 0.6188 - loss: 0.6215 - val_accuracy: 0.6379 - val_loss: 0.6115
# Epoch 15/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.6880 - loss: 0.5968 - val_accuracy: 0.6379 - val_loss: 0.5991
# Epoch 16/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.6660 - loss: 0.6168 - val_accuracy: 0.7069 - val_loss: 0.5783
# Epoch 17/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - accuracy: 0.6616 - loss: 0.6116 - val_accuracy: 0.7241 - val_loss: 0.5872
# Epoch 18/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - accuracy: 0.6645 - loss: 0.6037 - val_accuracy: 0.7069 - val_loss: 0.5911
# Epoch 19/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step - accuracy: 0.6658 - loss: 0.6060 - val_accuracy: 0.6897 - val_loss: 0.5862
# Epoch 20/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step - accuracy: 0.6387 - loss: 0.6300 - val_accuracy: 0.6897 - val_loss: 0.5744
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss =model_history2.history['loss']
val_loss =model_history2.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.76       130
#            1       0.50      0.48      0.49        62
#
#     accuracy                           0.68       192
#    macro avg       0.63      0.63      0.63       192
# weighted avg       0.67      0.68      0.68       192
#
# [[100  30]
#  [ 32  30]]

# %% [markdown]
# ## < Transformer >

# %%
# 데이터 불러오기 (csv, xlsx)

df = pd.read_csv("C:/ai/DSA_features.csv")
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 9115     0.200829     -0.040701      0.297666     0.708480    -0.117430
# 9116     0.148745     -0.266377      0.224716     0.554670    -0.250950
# 9117     0.310748     -0.009505     -0.237786     0.088854    -0.477260
# 9118     0.156493      0.050624      0.533023     0.677800     0.055941
# 9119     0.229154     -0.342228      0.491919     0.707920     0.251280
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity  people
# 0     6.778722e-07     0.000823      0.036729     sitting      p1
# 1     7.032302e-07     0.000839      0.347471     sitting      p1
# 2     6.268222e-07     0.000792      0.045579     sitting      p1
# 3     8.011245e-07     0.000895      0.240690     sitting      p1
# 4     6.853423e-07     0.000828      0.258429     sitting      p1
# ...            ...          ...           ...         ...     ...
# 9115  4.135451e-02     0.203358     -0.310022  basketBall      p8
# 9116  3.355704e-02     0.183186     -0.736410  basketBall      p8
# 9117  2.026107e-02     0.142341      0.668438  basketBall      p8
# 9118  1.356379e-02     0.116464     -1.482489  basketBall      p8
# 9119  9.358254e-03     0.096738     -0.223302  basketBall      p8
#
# [9120 rows x 272 columns]

# %%
for i in df.columns:
    # LabelEncoder 객체 생성
    label_encoder = LabelEncoder()
    # 'label' 컬럼을 숫자로 변환
    df[i] = LabelEncoder().fit_transform(df[i])
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0            1824        1201        6229        2129        2129
# 1            1829        1206        6365        2027        2027
# 2            1819        1179        6364        1674        1674
# 3            1793        1184        6240        1769        1769
# 4            1768        1194        6354        1311        1311
# ...           ...         ...         ...         ...         ...
# 9115         2172        6784        1403        7972        7972
# 9116         7405        7298        1247        8057        8057
# 9117         7464        6452        1740        8153        8153
# 9118         8146        7476        1433        8208        8208
# 9119         5856        7193        1211        8093        8093
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0            2972         8548        3588        8343        1646  ...
# 1            5743         8590        3641        8362         530  ...
# 2            3636         8591        3640        8368         227  ...
# 3            1969         8606        3853        8366        1632  ...
# 4            9052         8632        3717        8378         372  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115         8502         1765        8300         390        8908  ...
# 9116         9105         6651        7938         383        8108  ...
# 9117         5305         3110        7080        1089        8153  ...
# 9118         9118         3545        7811         896        7908  ...
# 9119         8913         5059        7759        1421        7881  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0             674          6839          3211         1960         4164
# 1             814          2752          3207         1961         4154
# 2             578          4013          3214         1969         4172
# 3             459          5532          3248         2002         4205
# 4             742          3889          3262         2007         4215
# ...           ...           ...           ...          ...          ...
# 9115         7907          4951          6862         8180         3669
# 9116         6255          2928          6063         7189         2863
# 9117         9006          5238          1772         3130         1070
# 9118         6510          5814          8280         7988         5296
# 9119         8479          2288          8115         8175         6848
#
#       LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity  people
# 0             877          877          5593        12       0
# 1             912          912          7434        12       0
# 2             774          774          5657        12       0
# 3            1016         1016          6906        12       0
# 4             886          886          7001        12       0
# ...           ...          ...           ...       ...     ...
# 9115         8798         8798          2887         1       7
# 9116         8683         8683           945         1       7
# 9117         8389         8389          8299         1       7
# 9118         7829         7829           137         1       7
# 9119         7271         7271          3455         1       7
#
# [9120 rows x 272 columns]

# %%
X=df.drop('activity',axis=1)
y=df['activity']
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=0)
X_train = np.expand_dims(X_train, axis=-1)
print(X.shape)
print(y.shape)
# Out:
# (9120, 271)
# (9120,)

# %%
from keras import layers
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(res)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(1)(x)
    return keras.Model(inputs, outputs)

# %%
print(X_train.shape[1:])
# Out:
# (271, 1)

# %%
#input_shape = X_train_padded.shape
input_shape = X_train.shape[1:]
#input_shape = (X_train.shape[1],1)
print("input: {}".format(input_shape))

model = build_model(
    input_shape,
    head_size=16,
    num_heads=3,
    ff_dim=3,
    num_transformer_blocks=3,
    mlp_units=[32],
    mlp_dropout=0.2,
    dropout=0.1,)

model.compile(
    loss="categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=["categorical_accuracy"],)
model.summary()
# Out:
# input: (271, 1)
# Model: "functional_258"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_58      │ (None, 271, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 271, 1)    │        337 │ input_layer_58[0… │
# │ (MultiHeadAttentio… │                   │            │ input_layer_58[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_41          │ (None, 271, 1)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 271, 1)    │          2 │ dropout_41[0][0]  │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 271, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ input_layer_58[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_13 (Conv1D)  │ (None, 271, 3)    │          6 │ add_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_42          │ (None, 271, 3)    │          0 │ conv1d_13[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_14 (Conv1D)  │ (None, 271, 1)    │          4 │ dropout_42[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 271, 1)    │          2 │ conv1d_14[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 271, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 271, 1)    │        337 │ add_14[0][0],     │
# │ (MultiHeadAttentio… │                   │            │ add_14[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_44          │ (None, 271, 1)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 271, 1)    │          2 │ dropout_44[0][0]  │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 271, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_14[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_15 (Conv1D)  │ (None, 271, 3)    │          6 │ add_15[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_45          │ (None, 271, 3)    │          0 │ conv1d_15[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_16 (Conv1D)  │ (None, 271, 1)    │          4 │ dropout_45[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 271, 1)    │          2 │ conv1d_16[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 271, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_15[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 271, 1)    │        337 │ add_16[0][0],     │
# │ (MultiHeadAttentio… │                   │            │ add_16[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_47          │ (None, 271, 1)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 271, 1)    │          2 │ dropout_47[0][0]  │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 271, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_16[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_17 (Conv1D)  │ (None, 271, 3)    │          6 │ add_17[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_48          │ (None, 271, 3)    │          0 │ conv1d_17[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_18 (Conv1D)  │ (None, 271, 1)    │          4 │ dropout_48[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 271, 1)    │          2 │ conv1d_18[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 271, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_17[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1)         │          0 │ add_18[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_206 (Dense)   │ (None, 32)        │         64 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_49          │ (None, 32)        │          0 │ dense_206[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_207 (Dense)   │ (None, 1)         │         33 │ dropout_49[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,150 (4.49 KB)
#  Trainable params: 1,150 (4.49 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]
#X_train = X_train.reshape(X_train.shape[0],X_train.shape[1],1) ### 보정
#y_train = np.argmax(y_train, axis=1) ### 보정

model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs=10,
    batch_size=256,
    callbacks=callbacks,
)
# Out:
# Epoch 1/10
# C:\Users\1563a\anaconda3\lib\site-packages\keras\src\losses\losses.py:22: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - categorical_accuracy: 1.0000 - loss: 1.0830e-06 - val_categorical_accuracy: 1.0000 - val_loss: 1.0693e-06
# Epoch 2/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - categorical_accuracy: 1.0000 - loss: 1.0852e-06 - val_categorical_accuracy: 1.0000 - val_loss: 1.0693e-06
# Epoch 3/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - categorical_accuracy: 1.0000 - loss: 1.0801e-06 - val_categorical_accuracy: 1.0000 - val_loss: 1.0693e-06
# Epoch 4/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - categorical_accuracy: 1.0000 - loss: 1.0824e-06 - val_categorical_accuracy: 1.0000 - val_loss: 1.0693e-06
# Epoch 5/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - categorical_accuracy: 1.0000 - loss: 1.0862e-06 - val_categorical_accuracy: 1.0000 - val_loss: 1.0693e-06
# Epoch 6/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - categorical_accuracy: 1.0000 - loss: 1.0778e-06 - val_categorical_accuracy: 1.0000 - val_loss: 1.0693e-06
# Epoch 7/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - categorical_accuracy: 1.0000 - loss: 1.0931e-06 - val_categorical_accuracy: 1.0000 - val_loss: 1.0693e-06
# Epoch 8/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - categorical_accuracy: 1.0000 - loss: 1.0889e-06 - val_categorical_accuracy: 1.0000 - val_loss: 1.0693e-06
# Epoch 9/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - categorical_accuracy: 1.0000 - loss: 1.0847e-06 - val_categorical_accuracy: 1.0000 - val_loss: 1.0693e-06
# Epoch 10/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - categorical_accuracy: 1.0000 - loss: 1.0820e-06 - val_categorical_accuracy: 1.0000 - val_loss: 1.0693e-06

# %%
X_test = np.expand_dims(X_test, axis=-1)
model.evaluate(X_test, y_test, verbose=1)
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - categorical_accuracy: 1.0000 - loss: 1.0565e-06
# [1.0547229294388671e-06, 1.0]

# %% [markdown]
# ## < AE >

# %%
# 데이터 불러오기 (csv, xlsx)

df = pd.read_csv("C:/ai/DSA_features.csv")
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 9115     0.200829     -0.040701      0.297666     0.708480    -0.117430
# 9116     0.148745     -0.266377      0.224716     0.554670    -0.250950
# 9117     0.310748     -0.009505     -0.237786     0.088854    -0.477260
# 9118     0.156493      0.050624      0.533023     0.677800     0.055941
# 9119     0.229154     -0.342228      0.491919     0.707920     0.251280
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity  people
# 0     6.778722e-07     0.000823      0.036729     sitting      p1
# 1     7.032302e-07     0.000839      0.347471     sitting      p1
# 2     6.268222e-07     0.000792      0.045579     sitting      p1
# 3     8.011245e-07     0.000895      0.240690     sitting      p1
# 4     6.853423e-07     0.000828      0.258429     sitting      p1
# ...            ...          ...           ...         ...     ...
# 9115  4.135451e-02     0.203358     -0.310022  basketBall      p8
# 9116  3.355704e-02     0.183186     -0.736410  basketBall      p8
# 9117  2.026107e-02     0.142341      0.668438  basketBall      p8
# 9118  1.356379e-02     0.116464     -1.482489  basketBall      p8
# 9119  9.358254e-03     0.096738     -0.223302  basketBall      p8
#
# [9120 rows x 272 columns]

# %%
RANDOM_SEED = 42
X_train, X_test = train_test_split(df, test_size=0.2, random_state=RANDOM_SEED)

# %%
print(len(df['activity'].unique()))
print(df['activity'].unique())
# Out:
# 19
# ['sitting' 'standing' 'lyingBack' 'lyingRigh' 'ascendingStairs'
#  'decendingStairs' 'standingInElevatorStill' 'movingInElevator'
#  'walkingLot' 'walkingTreadmillFlat' 'walkingTreadmillIncline'
#  'runningTreadmill' 'stepper' 'crossTrainer' 'cyclingHorizontal'
#  'cyclingVertical' 'rowing' 'jumping' 'basketBall']

# %%
#'lyingBack', 'lyingRigh'
X_train = X_train[X_train['activity'].isin(['lyingBack', 'lyingRigh'])]

for i in ['activity','people']:
    label_encoder = LabelEncoder()
    X_train[i] = LabelEncoder().fit_transform(X_train[i])
    X_test[i] = LabelEncoder().fit_transform(X_test[i])
    
X_train = X_train.drop(['activity'], axis=1).values

y_test = X_test['activity']
X_test = X_test.drop(['activity'], axis=1).values
print(X_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (755, 271)
# (1824, 271)
# (1824,)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

# 오토인코더 모델 (대칭형)

encoding_dim = 24  # 인코딩 차원을 설정 (임의로 설정한 값, 조정 가능)

input_layer = Input(shape=(X_train.shape[1],))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
encoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
encoded = Dense(int(encoding_dim / 3), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 3), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(X_train.shape[1], activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer=Adam(learning_rate=0.0001), loss='mse')

# 모델 요약 출력
autoencoder.summary()
# Out:
# Model: "functional_306"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_82 (InputLayer)     │ (None, 271)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_360 (Dense)               │ (None, 24)             │         6,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_361 (Dense)               │ (None, 12)             │           300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_362 (Dense)               │ (None, 8)              │           104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_364 (Dense)               │ (None, 12)             │           108 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_365 (Dense)               │ (None, 271)            │         3,523 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,563 (41.26 KB)
#  Trainable params: 10,563 (41.26 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = autoencoder.fit(X_train, X_train, 
                          epochs=20, 
                          batch_size=4, 
                          shuffle=True, 
                          validation_split = 0.1)
# Out:
# Epoch 1/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 893us/step - loss: 5.7151 - val_loss: 6.1925
# Epoch 2/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - loss: 5.5860 - val_loss: 5.8860
# Epoch 3/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - loss: 5.2572 - val_loss: 5.5819
# Epoch 4/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - loss: 5.0057 - val_loss: 5.4669
# Epoch 5/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - loss: 4.9759 - val_loss: 5.4457
# Epoch 6/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - loss: 4.9568 - val_loss: 5.4391
# Epoch 7/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - loss: 4.8946 - val_loss: 5.4343
# Epoch 8/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - loss: 4.9269 - val_loss: 5.4300
# Epoch 9/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - loss: 4.8864 - val_loss: 5.4254
# Epoch 10/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - loss: 4.9081 - val_loss: 5.4200
# Epoch 11/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - loss: 4.8794 - val_loss: 5.4160
# Epoch 12/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - loss: 4.8903 - val_loss: 5.4124
# Epoch 13/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - loss: 4.8569 - val_loss: 5.4096
# Epoch 14/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - loss: 4.8569 - val_loss: 5.4071
# Epoch 15/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - loss: 4.8924 - val_loss: 5.4051
# Epoch 16/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - loss: 4.8392 - val_loss: 5.4035
# Epoch 17/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - loss: 4.8516 - val_loss: 5.4013
# Epoch 18/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - loss: 4.8716 - val_loss: 5.3997
# Epoch 19/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - loss: 4.8631 - val_loss: 5.3981
# Epoch 20/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step - loss: 4.8653 - val_loss: 5.3971

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

# %%
predictions = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step
#        reconstruction_error   true_class
# count           1824.000000  1824.000000
# mean              81.172053     9.074013
# std              205.075039     5.487282
# min                4.557893     0.000000
# 25%                5.363449     4.000000
# 50%               11.589587     9.000000
# 75%               23.588853    14.000000
# max             2032.519636    18.000000

# %%
error_df.head()
# Out:
#       reconstruction_error  true_class
# 8225             48.043812           6
# 3133              4.931151          14
# 1446              4.933618           8
# 4568             43.384571          17
# 6022              8.898940          15

# %%
# threshold 값을 조정하여 최선의 정확도를 얻음, 그래프로를 보고 결정

threshold = 16

#groups = error_df.groupby('true_class')
error_df=error_df[error_df['true_class'].isin([0, 2, 3])]
error_df['true_class'] = error_df['true_class'].replace({2: 1, 3: 1})
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 0 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
y_pred = [1 if e > threshold else 0 for e in error_df[error_df['true_class'].isin([0, 1])].reconstruction_error.values]
print(classification_report(error_df[error_df['true_class'].isin([0, 1])].true_class, y_pred))
#print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.95      0.60        94
#            1       0.92      0.34      0.49       173
#
#     accuracy                           0.55       267
#    macro avg       0.68      0.64      0.54       267
# weighted avg       0.75      0.55      0.53       267

# %%
# Denosing
df_denoise = df.copy()
df_noise = df.copy()
noise_factor = 0.5

for i in ['people']:
    label_encoder = LabelEncoder()
    df_denoise[i] = LabelEncoder().fit_transform(df_denoise[i])
    df_noise[i] = LabelEncoder().fit_transform(df_noise[i])

for i in df.columns:
    if not i=="activity":
        noise = noise_factor * np.random.normal(loc=0.0, scale=1.0, size=len(df[i]))
        df_noise[i] += noise

print(df_denoise.values)
print(df_noise.values)
# Out:
# [[7.975714399999999 8.1605 7.6823 ... 0.036728963831605 'sitting' 0]
#  [7.978249600000001 8.1763 7.8472 ... 0.34747102652112 'sitting' 0]
#  [7.970893599999999 8.086 7.847 ... 0.0455789433658793 'sitting' 0]
#  ...
#  [9.599112887999995 27.93 -1.0765 ... 0.6684382188037419 'basketBall' 7]
#  [9.692482224 72.782 -2.6734 ... -1.482488998951602 'basketBall' 7]
#  [9.380640912000002 45.009 -3.5938 ... -0.2233022030386714 'basketBall' 7]]
# [[8.296649931864215 7.620860557317567 8.47605129890825 ...
#   -0.9000734240289543 'sitting' 0.3621894992855367]
#  [7.606531983470093 8.518681311573376 7.06641824081872 ...
#   0.16710014644500995 'sitting' -0.4746449783810728]
#  [8.047173006189535 7.0559219490177645 7.791833218960031 ...
#   0.015549562852208022 'sitting' 0.07669486798263926]
#  ...
#  [9.681075062491528 27.383664292393743 -0.6248980981032172 ...
#   0.4500506020848756 'basketBall' 7.736260337686916]
#  [9.974328864661453 73.19077364580136 -2.4023963357960283 ...
#   -0.9590894990270578 'basketBall' 7.306609872612276]
#  [8.800048684304876 45.37977808606049 -4.528776533127646 ...
#   -1.028898141315476 'basketBall' 7.746216455620537]]

# %%
RANDOM_SEED = 42
X_train, X_test = train_test_split(df_noise, test_size=0.2, random_state=RANDOM_SEED)

X_train = X_train[X_train['activity'].isin(['lyingBack', 'lyingRigh'])]

for i in ['activity']:
    label_encoder = LabelEncoder()
    X_train[i] = LabelEncoder().fit_transform(X_train[i])
    X_test[i] = LabelEncoder().fit_transform(X_test[i])
    
X_train = X_train.drop(['activity'], axis=1).values

y_test = X_test['activity']
X_test = X_test.drop(['activity'], axis=1).values
print(X_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (755, 271)
# (1824, 271)
# (1824,)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

# 오토인코더 모델 (비대칭형)

encoding_dim = 60  # 인코딩 차원을 설정 (임의로 설정한 값, 조정 가능)

input_layer = Input(shape=(X_train.shape[1],))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
encoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
encoded = Dense(int(encoding_dim / 4), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 5), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 3), activation='relu')(encoded)
decoded = Dense(X_train.shape[1], activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer=Adam(learning_rate=0.0001), loss='mse')

# 모델 요약 출력
autoencoder.summary()
# Out:
# Model: "functional_314"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_86 (InputLayer)     │ (None, 271)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_384 (Dense)               │ (None, 60)             │        16,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_385 (Dense)               │ (None, 30)             │         1,830 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_386 (Dense)               │ (None, 15)             │           465 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_388 (Dense)               │ (None, 20)             │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_389 (Dense)               │ (None, 271)            │         5,691 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,626 (96.20 KB)
#  Trainable params: 24,626 (96.20 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = autoencoder.fit(X_train, X_train, 
                          epochs=20, 
                          batch_size=4, 
                          shuffle=True, 
                          validation_split = 0.1)
# Out:
# Epoch 1/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 900us/step - loss: 5.9292 - val_loss: 6.2665
# Epoch 2/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - loss: 5.5892 - val_loss: 5.8597
# Epoch 3/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - loss: 5.2774 - val_loss: 5.7689
# Epoch 4/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - loss: 5.2224 - val_loss: 5.7349
# Epoch 5/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - loss: 5.1567 - val_loss: 5.7090
# Epoch 6/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - loss: 5.1419 - val_loss: 5.6955
# Epoch 7/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - loss: 5.1328 - val_loss: 5.6830
# Epoch 8/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - loss: 5.0775 - val_loss: 5.6773
# Epoch 9/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - loss: 5.1395 - val_loss: 5.6747
# Epoch 10/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - loss: 5.0968 - val_loss: 5.6734
# Epoch 11/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - loss: 5.1126 - val_loss: 5.6725
# Epoch 12/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - loss: 5.1092 - val_loss: 5.6717
# Epoch 13/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - loss: 5.0902 - val_loss: 5.6703
# Epoch 14/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - loss: 5.1117 - val_loss: 5.6692
# Epoch 15/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 5.0982 - val_loss: 5.6682
# Epoch 16/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - loss: 5.0791 - val_loss: 5.6674
# Epoch 17/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - loss: 5.1085 - val_loss: 5.6672
# Epoch 18/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - loss: 5.0725 - val_loss: 5.6667
# Epoch 19/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 5.0761 - val_loss: 5.6659
# Epoch 20/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - loss: 5.0603 - val_loss: 5.6649

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

# %%
predictions = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step
#        reconstruction_error   true_class
# count           1824.000000  1824.000000
# mean              81.376780     9.074013
# std              205.041935     5.487282
# min                4.580349     0.000000
# 25%                5.680895     4.000000
# 50%               11.855725     9.000000
# 75%               23.825248    14.000000
# max             2031.676260    18.000000

# %%
error_df.head()
# Out:
#       reconstruction_error  true_class
# 8225             48.070774           6
# 3133              5.403616          14
# 1446              5.163618           8
# 4568             43.650837          17
# 6022              9.168363          15

# %%
# threshold 값을 조정하여 최선의 정확도를 얻음, 그래프로를 보고 결정

threshold = 16

#groups = error_df.groupby('true_class')
#error_df=error_df[error_df['true_class'].isin([0, 2, 3])]
#error_df['true_class'] = error_df['true_class'].replace({2: 1, 3: 1})
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 0 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
y_pred = [1 if e > threshold else 0 for e in error_df[error_df['true_class'].isin([0, 1])].reconstruction_error.values]
print(classification_report(error_df[error_df['true_class'].isin([0, 1])].true_class, y_pred))
#print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.94      0.59        94
#            1       0.91      0.34      0.50       173
#
#     accuracy                           0.55       267
#    macro avg       0.67      0.64      0.55       267
# weighted avg       0.74      0.55      0.53       267

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
LABELS = ["Normal", "Fraud"]

y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.94      0.59        94
#            1       0.91      0.34      0.50       173
#
#     accuracy                           0.55       267
#    macro avg       0.67      0.64      0.55       267
# weighted avg       0.74      0.55      0.53       267
